# %%
import pandas as pd
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.max_rows', None) 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv('C:\\Users\\PIYALI\\Final_housePricedata.csv')

# %%
y=df['SalePrice']
X=df.drop(columns='SalePrice')

# %%
data = pd.concat([X, y], axis=1)

correlation_matrix = data.corr()

print("Correlation with target variable (y):\n")
print(correlation_matrix['SalePrice'].sort_values(ascending=False))
# Out:
# Correlation with target variable (y):
#
# SalePrice                1.000000
# OverallQual              0.795428
# GrLivArea                0.705995
# ExterQual                0.687601
# KitchenQual              0.662522
# GarageCars               0.640817
# Total_Bathrooms          0.636213
# GarageArea               0.628653
# 1stFlrSF                 0.598119
# BsmtQual                 0.586438
# YrBltAndRemod            0.575629
# FullBath                 0.563983
# GarageFinish             0.548545
# TotRmsAbvGrd             0.544641
# FireplaceQu              0.520779
# Foundation               0.475291
# hasfireplace             0.471527
# Fireplaces               0.468925
# OpenPorchSF              0.430552
# Total_porch_sf           0.429305
# HeatingQC                0.424280
# MasVnrArea               0.412541
# Neighborhood_NridgHt     0.402360
# LotArea                  0.390904
# BsmtExposure             0.376573
# SaleType_New             0.360638
# ...

# %%
plt.scatter(df['OverallQual'],df['SalePrice'])

# %%
plt.scatter(df['ExterQual'],df['SalePrice'])

# %%
plt.scatter(df['Total_Bathrooms'],df['SalePrice'])

# %%
plt.scatter(df['MasVnrType_None'],df['SalePrice'])

# %% [markdown]
# # MULTICOLLINEARITY

# %%
df['GarageArea'].corr(df['GarageCars'])
# Out:
# 0.8851780385847827

# %%
df['GarageArea'].corr(y)
# Out:
# 0.6286534243705059

# %%
df['GarageCars'].corr(y)
# Out:
# 0.6408171752265989

# %%
plt.scatter(df['GarageCars'],y)

# %%
plt.scatter(df['GarageArea'],y)

# %% [markdown]
# # Log TRANSFORM OF SALEPRICE

# %%
sns.kdeplot(y)
# Out:
# <Axes: xlabel='SalePrice', ylabel='Density'>

# %%
sns.kdeplot(np.log1p(y))
# Out:
# <Axes: xlabel='SalePrice', ylabel='Density'>

# %%
y=np.log1p(y)

# %% [markdown]
# # Feature Scaling

# %%
scaler=MinMaxScaler()
scaler.fit(X)
# Out:
# MinMaxScaler()

# %%
X=pd.DataFrame(scaler.transform(X),columns=X.columns)

# %%
pd.concat([X,y],axis=1).to_csv('Ready_data.csv')
